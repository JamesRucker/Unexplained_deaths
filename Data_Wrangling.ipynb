# %%
# Import Dependencies
import pandas as pd

# Data is pulled from csv
raw_data_df = pd.read_csv("data/Weekly_Counts_of_Deaths_by_State_and_Select_Causes__2014-2018_studydata.csv")
raw_data_df
# Out:
#         jurisdiction Week Ending Date  all_cause  septicemia   cancer  \
# 0            Alabama         1/4/2014        355         NaN     60.0
# 1            Alabama        1/11/2014        872        23.0    163.0
# 2            Alabama        1/18/2014       1044        21.0    209.0
# 3            Alabama        1/25/2014       1022        25.0    205.0
# 4            Alabama         2/1/2014       1040        18.0    200.0
# ...              ...              ...        ...         ...      ...
# 14089  United States        12/1/2018      55210       766.0  11405.0
# 14090  United States        12/8/2018      56095       814.0  11715.0
# 14091  United States       12/15/2018      56530       823.0  11917.0
# 14092  United States       12/22/2018      56689       850.0  11753.0
# 14093  United States       12/29/2018      56163       799.0  11441.0
#
#        diabetes  Alzheimers  influenza_pneumonia  chronic_LRD  \
# 0           NaN        10.0                  NaN         20.0
# ...
