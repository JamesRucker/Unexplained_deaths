# %%
# Import dependencies
import pandas as pd

# Grab finished Dataframe
death_df = pd.read_csv("../Data/final_death_data.csv")
death_df
# Out:
#       jurisdiction week_end_date     all_cause  septicemia        cancer  \
# 0    United States    10/11/2014  47936.706552  672.086975  11269.826525
# 1    United States    10/18/2014  47948.045442  712.288496  11135.821454
# 2    United States    10/25/2014  47709.928738  648.378385  11158.499235
# 3    United States     11/1/2014  47638.802969  709.196071  11166.745701
# 4    United States     11/8/2014  49680.834100  697.857181  11222.409346
# ..             ...           ...           ...         ...           ...
# 307  United States     8/29/2020  57553.000000  699.000000  10957.000000
# 308  United States      9/5/2020  56507.000000  656.000000  10721.000000
# 309  United States     9/12/2020  56005.000000  640.000000  10783.000000
# 310  United States     9/19/2020  55923.000000  705.000000  10944.000000
# 311  United States     9/26/2020  56905.000000  705.000000  11219.000000
#
#         diabetes   Alzheimers  influenza_pneumonia  chronic_LRD  \
# ...

# %%
# Dataframes for 2019 season and 2-, 3-, and 5-year average before 2019 season are crafted then exported

# Arrays to grab years of interest.  Season week 0 corresponds to 2014, with incrementing values incrementing year.
season_numb = [[5], [3,4], [2,3,4], [0,1,2,3,4]]
title = ["2019_season", "2_year_average", "3_year_average", "5_year_average"]

# Loop through all relevant averages
for i in range(4):
    
    # Data for relevant seasons are extracted
    data_df = death_df.loc[death_df["season"].isin(season_numb[i])].drop("season", axis=1)

    # Data is grouped by season_week, averaged, and the resulting dataframe is exported to csv
    average_df = data_df.groupby("season_week").mean()
    average_df.to_csv(f'../Data/Aggregated_{title[i]}.csv')
